# %%
import numpy as np
import matplotlib.pylab as plt

import os

from yolo import YOLO
from PIL import Image
import time
from IPython.display import clear_output

# %%
ext = '_mouse'
yoloObj = YOLO(model_path = "logs/trained_weights_final" + ext + ".h5",
     classes_path = 'model_data/' +ext[1:]+ '_classes.txt' ,
     anchors_path = 'model_data/yolo_anchors' + ext + '.txt',
    model_image_size = (128,448),
              gpu_num = 0,
              score = 0.5,
              iou = 0.4)
# Out:
# WARNING:tensorflow:From /Users/raminanushiravani/opt/anaconda3/lib/python3.8/site-packages/keras/layers/normalization/batch_normalization.py:532: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# logs/trained_weights_final_mouse.h5 model, anchors, and classes loaded.

# %%
image_path = "/Users/raminanushiravani/Desktop/mouse_videos/healthy/healthy_NSG336_1_20cms_0degUP/frames/"
files = sorted(os.listdir(image_path), key = lambda x : int(x.split('.')[0]))
files_abs_path = [image_path+f for f in files ]

# %%
for f in files_abs_path:
    figure, ax = plt.subplots(1,figsize=(40,20))
    image = Image.open(f)
    image_data = np.array(image)[:,0:580,:]
    image_ = Image.fromarray(image_data.astype('uint8'), 'RGB')
    i = yoloObj.detect_image(image_)
    ax.imshow(i)
    plt.show()
    time.sleep(0.01)
    clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-6318955eb371> in <module>
#       4     image_data = np.array(image)[:,0:580,:]
#       5     image_ = Image.fromarray(image_data.astype('uint8'), 'RGB')
# ----> 6     i = yoloObj.detect_image(image_)
#       7     ax.imshow(i)
#       8     plt.show()
#
# ~/Desktop/mouse_videos/Yolo_fine_tunning/yolo.py in detect_image(self, image)
#     123
#     124         out_boxes, out_scores, out_classes = self.sess.run(
# --> 125             [self.boxes, self.scores, self.classes],
#     126             feed_dict={
#     127                 self.yolo_model.input: image_data,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     968
#     969     try:
# --> 970       result = self._run(None, fetches, feed_dict, options_ptr,
# ...

# %%
image_data.shape
image_data
# Out:
# array([[[147, 151, 126],
#         [143, 147, 122],
#         [138, 142, 117],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[164, 168, 145],
#         [162, 166, 143],
#         [160, 164, 141],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[211, 214, 193],
#         [211, 214, 193],
#         [211, 214, 193],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 87,  83,  71],
#         [ 84,  80,  68],
#         [ 85,  82,  67],
#         ...,
#         [121, 119,  98],
#         [123, 121, 100],
#         [122, 120,  99]],
#
#        [[ 83,  79,  67],
#         [ 80,  76,  64],
#         [ 81,  78,  63],
#         ...,
#         [109, 107,  86],
#         [111, 109,  88],
#         [111, 109,  88]],
#
#        [[ 81,  77,  65],
#         [ 78,  74,  62],
#         [ 79,  76,  61],
# ...

# %%
image.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1c83375060d0> in <module>
# ----> 1 image.shape
#
# ~/opt/anaconda3/lib/python3.8/site-packages/PIL/Image.py in __getattr__(self, name)
#     539             )
#     540             return self._category
# --> 541         raise AttributeError(name)
#     542
#     543     @property
#
# AttributeError: shape
